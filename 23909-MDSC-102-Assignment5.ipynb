# %% [markdown]
# BOXPLOT

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"C:\Users\Msc 1\Desktop\wine\wine.data")
dataset
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %%
dataset.columns =['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids','Nonflavanoid phenols',
'Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline' ]
dataset
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    13.20        1.78  2.14               11.2        100
# 1        1    13.16        2.36  2.67               18.6        101
# 2        1    14.37        1.95  2.50               16.8        113
# 3        1    13.24        2.59  2.87               21.0        118
# 4        1    14.20        1.76  2.45               15.2        112
# ..     ...      ...         ...   ...                ...        ...
# 172      3    13.71        5.65  2.45               20.5         95
# 173      3    13.40        3.91  2.48               23.0        102
# 174      3    13.27        4.28  2.26               20.0        120
# 175      3    13.17        2.59  2.37               20.0        120
# 176      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.65        2.76                  0.26             1.28
# ...

# %%
sns.boxplot(x=dataset["Ash"])
# Out:
# <Axes: xlabel='Ash'>

# %%
i=1
plt.figure(figsize=(20,20))
for feature in dataset:
    if feature!='Class' and feature!='Alcohol':
        plt.subplot(4,3,i)
        sns.boxplot(x=dataset['Class'],y=dataset[feature], hue=dataset['Class'])
        i+=1

# %%
i=1
plt.figure(figsize=(20,20))
for feature in dataset:
    if feature!='Class' and feature!='Alcohol':
        plt.subplot(4,3,i)
        sns.histplot(x=dataset[feature], hue=dataset['Class'])
        i+=1

# %% [markdown]
# Inferences

# %%
# 1) class 1:seems to be right skewed
#    class 2:seems to be right skewed
#    class 3:Normal

# 2) class 1:Normal
#    class 2:seems to be right skewed
#    class 3:seems to be right skewed

# 3) class 1:seems to be left skewed
#    class 2:seems to be right skewed
#    class 3:seems to be right skewed

# 4) class 1:seems to be right skewed
#    class 2:Normal
#    class 3:seems to be right skewed

# 5) class 1:Normal
#    class 2:seems to be right skewed
#    class 3:Normal

# 6) class 1:seems to be right skewed
#    class 2:seems to be right skewed
#    class 3:seems to be right skewed

# 7) class 1:seems to be right skewed
#    class 2:seems to be right skewed
#    class 3:seems to be left skewed

# 8) class 1:Normal
#    class 2:seems to be left skewed
#    class 3:seems to be right skewed

# 9) class 1:seems to be right skewed
#    class 2:seems to be right skewed
#    class 3:seems to be right skewed

# 10) class 1:seems to be left skewed
#     class 2:Normal
#     class 3:seems to be right skewed

# 11) class 1:seems to be right skewed
#     class 2:seems to be left skewed
#     class 3:seems to be right skewed

# 12) class 1:seems to be right skewed
#     class 2:seems to be right skewed
#     class 3:seems to be right skewed
