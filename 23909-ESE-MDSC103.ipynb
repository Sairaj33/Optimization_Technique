# %%
import numpy as np
import scipy as sp
from scipy.optimize import minimize
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# %%
fun =lambda x, y:4*x+6*y-2*x**2-2*x*y-2*y**2 
x = np.linspace(-5,5,100)
y = np.linspace(-1,5,100)

X, Y = np.meshgrid(x,y)
F = fun(X,Y)

fig = plt.figure(figsize=(12,8))
ax = plt.subplot(1,2,1,projection='3d') 
ax.scatter3D(1,1,fun(1,1),c="red",marker="o",s=100)#3D plot
surf = ax.plot_surface(X,Y,F, cmap= 'gist_rainbow')
fig.colorbar(surf,shrink=0.5, aspect=15)
# set  labels
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(X)')

plt.show()

# %%
#maximize the function by multiplying a minus to the function
e =lambda x: -4*x[0]-6*x[1]+2*x[0]**2+2*x[0]*x[1]+2*x[1]**2 
x0 = [0.5,2] #initial guess point
result = minimize(e,x0)
result
# Out:
#   message: Optimization terminated successfully.
#   success: True
#    status: 0
#       fun: -4.666666666661008
#         x: [ 3.333e-01  1.333e+00]
#       nit: 6
#       jac: [-2.384e-06  4.172e-06]
#  hess_inv: [[ 3.361e-01 -1.699e-01]
#             [-1.699e-01  3.372e-01]]
#      nfev: 21
#      njev: 7
