# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %%
ds = pd.read_csv(r"C:\Users\Msc 1\Desktop\wine\wine.data")
ds
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %%
ds.columns =['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids','Nonflavanoid phenols',
'Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline' ]
ds
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    13.20        1.78  2.14               11.2        100
# 1        1    13.16        2.36  2.67               18.6        101
# 2        1    14.37        1.95  2.50               16.8        113
# 3        1    13.24        2.59  2.87               21.0        118
# 4        1    14.20        1.76  2.45               15.2        112
# ..     ...      ...         ...   ...                ...        ...
# 172      3    13.71        5.65  2.45               20.5         95
# 173      3    13.40        3.91  2.48               23.0        102
# 174      3    13.27        4.28  2.26               20.0        120
# 175      3    13.17        2.59  2.37               20.0        120
# 176      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.65        2.76                  0.26             1.28
# ...

# %%
ds.info() # float : continuous
          # int: discrete
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Class                         177 non-null    int64
#  1   Alcohol                       177 non-null    float64
#  2   Malic acid                    177 non-null    float64
#  3   Ash                           177 non-null    float64
#  4   Alcalinity of ash             177 non-null    float64
#  5   Magnesium                     177 non-null    int64
#  6   Total phenols                 177 non-null    float64
#  7   Flavanoids                    177 non-null    float64
#  8   Nonflavanoid phenols          177 non-null    float64
#  9   Proanthocyanins               177 non-null    float64
#  10  Color intensity               177 non-null    float64
#  11  Hue                           177 non-null    float64
# ...

# %%
ds.columns #column names
# Out:
# Index(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue',
#        'OD280/OD315 of diluted wines', 'Proline'],
#       dtype='object')

# %%
ds.describe()#summary of the data
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  177.000000  177.000000  177.000000  177.000000         177.000000
# mean     1.943503   12.993672    2.339887    2.366158          19.516949
# std      0.773991    0.808808    1.119314    0.275080           3.336071
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.360000    1.600000    2.210000          17.200000
# 50%      2.000000   13.050000    1.870000    2.360000          19.500000
# 75%      3.000000   13.670000    3.100000    2.560000          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  177.000000     177.000000  177.000000            177.000000
# mean    99.587571       2.292260    2.023446              0.362316
# std     14.174018       0.626465    0.998658              0.124653
# ...

# %%
sns.boxplot(x=ds['Magnesium'],hue=ds["Class"])
plt.title("Boxplot for Magnesium")
# Out:
# Text(0.5, 1.0, 'Boxplot for Magnesium')

# %%
sns.histplot(x=ds['Magnesium'],kde=True)
plt.title("Histogram for Magnesium")
# Out:
# Text(0.5, 1.0, 'Histogram for Magnesium')

# %%
ds['Magnesium'].skew()
# Out:
# 1.1221477337039965

# %%
ds.skew()#skewness of the entire data
# Out:
# Class                           0.097941
# Alcohol                        -0.046483
# Malic acid                      1.030975
# Ash                            -0.172406
# Alcalinity of ash               0.204076
# Magnesium                       1.122148
# Total phenols                   0.097688
# Flavanoids                      0.036880
# Nonflavanoid phenols            0.440937
# Proanthocyanins                 0.532787
# Color intensity                 0.870850
# Hue                             0.026964
# OD280/OD315 of diluted wines   -0.320424
# Proline                         0.783800
# dtype: float64

# %%
sns.histplot(x=ds['OD280/OD315 of diluted wines'],kde=True)
plt.title("OD280/OD315 of diluted wines for Magnesium")
# Out:
# Text(0.5, 1.0, 'OD280/OD315 of diluted wines for Magnesium')

# %%
sns.boxplot(x=ds['OD280/OD315 of diluted wines'],hue=ds["Class"])
plt.title("Boxplot for OD280/OD315 of diluted wines")
# Out:
# Text(0.5, 1.0, 'Boxplot for OD280/OD315 of diluted wines')

# %%
plt.figure(figsize=(15,15))
plt.subplot(3,2,1)
sns.boxplot(y='Magnesium', data=ds)
plt.title("Boxplot for Magnesium")

plt.subplot(3,2,2)
sns.histplot(x="Magnesium", kde=True, data=ds)
plt.title("Histogram for Magnesium")

plt.subplot(3,2,3)
sns.boxplot(y='OD280/OD315 of diluted wines', data=ds)
plt.title("Boxplot for OD280/OD315 of diluted wines")

plt.subplot(3,2,4)
sns.histplot(x="OD280/OD315 of diluted wines", kde=True, data=ds)
plt.title("Histogram for OD280/OD315 of diluted wines")

plt.subplot(3,2,5)
sns.boxplot(y='Hue', data=ds)
plt.title("Boxplot for Hue")

plt.subplot(3,2,6)
sns.histplot(x="Hue", kde=True, data=ds)
plt.title("Histogram for Hue")

plt.savefig("./")
plt.show()

# %%
ds.skew()#Measures the skewness
# Out:
# Class                           0.097941
# Alcohol                        -0.046483
# Malic acid                      1.030975
# Ash                            -0.172406
# Alcalinity of ash               0.204076
# Magnesium                       1.122148
# Total phenols                   0.097688
# Flavanoids                      0.036880
# Nonflavanoid phenols            0.440937
# Proanthocyanins                 0.532787
# Color intensity                 0.870850
# Hue                             0.026964
# OD280/OD315 of diluted wines   -0.320424
# Proline                         0.783800
# dtype: float64

# %%
sns.histplot(x="OD280/OD315 of diluted wines", kde=True, data=ds)
plt.title("Histogram for OD280/OD315 of diluted wines")
# Out:
# Text(0.5, 1.0, 'Histogram for OD280/OD315 of diluted wines')

# %%
sns.histplot(x="Hue", kde=True, data=ds)
plt.title("Histogram for Hue")
# Out:
# Text(0.5, 1.0, 'Histogram for Hue')

# %%
ds["Magnesium"]
# Out:
# 0      100
# 1      101
# 2      113
# 3      118
# 4      112
#       ...
# 172     95
# 173    102
# 174    120
# 175    120
# 176     96
# Name: Magnesium, Length: 177, dtype: int64

# %%
log_Magnesium = np.log(ds["Magnesium"])
print(log_Magnesium)
print(log_Magnesium.skew())
# Out:
# 0      4.605170
# 1      4.615121
# 2      4.727388
# 3      4.770685
# 4      4.718499
#          ...
# 172    4.553877
# 173    4.624973
# 174    4.787492
# 175    4.787492
# 176    4.564348
# Name: Magnesium, Length: 177, dtype: float64
# 0.6127718613722887

# %%
sqrt_Magnesium = np.sqrt(ds["Magnesium"])
print(sqrt_Magnesium)
print(sqrt_Magnesium.skew())
# Out:
# 0      10.000000
# 1      10.049876
# 2      10.630146
# 3      10.862780
# 4      10.583005
#          ...
# 172     9.746794
# 173    10.099505
# 174    10.954451
# 175    10.954451
# 176     9.797959
# Name: Magnesium, Length: 177, dtype: float64
# 0.8552083333548858

# %%
Magnesium1 = 1 / ds["Magnesium"]
print(Magnesium1.skew())
# Out:
# -0.18002900457053003

# %%
Mag_boxcox, mag_lambda = sp.stats.boxcox(ds['Magnesium'])
print(mag_lambda)
# Out:
# -1.4382089996675784

# %%
magnesium_boxcox = ((((ds['Magnesium'])**mag_lambda) - 1) / mag_lambda)
print(magnesium_boxcox)
print(magnesium_boxcox.skew())
# Out:
# 0      0.694385
# 1      0.694398
# 2      0.694534
# 3      0.694581
# 4      0.694524
#          ...
# 172    0.694314
# 173    0.694411
# 174    0.694598
# 175    0.694598
# 176    0.694329
# Name: Magnesium, Length: 177, dtype: float64
# 0.003965846391651626

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,2,1)
sns.histplot(x="Magnesium", data = ds, kde = True)
plt.title("Histogram for Magnesium")
plt.subplot(1,2,2)
sns.histplot(x = magnesium_boxcox,data=magnesium_boxcox, kde = True)
plt.title("Histogram for Magnesium_boxcox")
plt.show()

# %%
fig,axes = plt.subplots(1,2,figsize=(15,4))
sp.stats.probplot(ds['Magnesium'], plot = axes[0])
axes[0].set_title("Magnesium probplot")
sp.stats.probplot(magnesium_boxcox, plot = axes[1])
axes[1].set_title("Magnesium_boxcox probplot")
plt.show()

# %%
ds.columns
# Out:
# Index(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue',
#        'OD280/OD315 of diluted wines', 'Proline'],
#       dtype='object')

# %%
ds1 = ds.copy()
ds1.head() # copying the dataset to another variable ds1
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    13.20        1.78  2.14               11.2        100
# 1      1    13.16        2.36  2.67               18.6        101
# 2      1    14.37        1.95  2.50               16.8        113
# 3      1    13.24        2.59  2.87               21.0        118
# 4      1    14.20        1.76  2.45               15.2        112
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.65        2.76                  0.26             1.28
# 1           2.80        3.24                  0.30             2.81
# 2           3.85        3.49                  0.24             2.18
# 3           2.80        2.69                  0.39             1.82
# 4           3.27        3.39                  0.34             1.97
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             4.38  1.05                          3.40     1050
# ...

# %%
del ds1['Class']

# %%
ds1.head()
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0    13.20        1.78  2.14               11.2        100           2.65
# 1    13.16        2.36  2.67               18.6        101           2.80
# 2    14.37        1.95  2.50               16.8        113           3.85
# 3    13.24        2.59  2.87               21.0        118           2.80
# 4    14.20        1.76  2.45               15.2        112           3.27
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        2.76                  0.26             1.28             4.38  1.05
# 1        3.24                  0.30             2.81             5.68  1.03
# 2        3.49                  0.24             2.18             7.80  0.86
# 3        2.69                  0.39             1.82             4.32  1.04
# 4        3.39                  0.34             1.97             6.75  1.05
#
#    OD280/OD315 of diluted wines  Proline
# ...

# %%
num_features = ds1.shape[1]# to count the no of columns available
print(num_features)
# Out:
# 13

# %%
i=1
plt.figure(figsize=(20,70))
for feature in ds1:
        #histogram
        plt.subplot(13,3,i)
        sns.histplot(x=ds1[feature],kde= True,color="#BB2525")
        plt.title("Histogram for {}".format(feature))
        i+=1
        # Boxplot
        plt.subplot(13,3,i)
        sns.boxplot(y=ds1[feature],data = ds1)
        plt.title("Boxplot for {}".format(feature))
        i+=1
        #probplot
        plt.subplot(13,3,i)
        sp.stats.probplot(x=ds1[feature], plot=plt)
        plt.title("Probability plot for {}".format(feature))
        plt.legend(labels=[f'skew:{ds1[feature].skew()}'],loc = 'lower right')
        i+=1

# %% [markdown]
# **Inference:**
# * Alcohol : Normal,skewness is around 0.
# * Malic Acid : Right skewed. Skew value is 1.1(positive)
# * Ash: left Skewed,the skew value is nearly -0.2.
# * Alcalinity of ash : slightly right skew, skew value: 0.2
# * Magnesium : Right Skewed , skew value : 1.2
# * Total Phenols: Normal
# * Flavanoids: Right Skewed , skewness is 0.4
# * Proanthocyanins:slightly Right Skewed, skewness is 0.5
# * color intensity: right skewed , skewness is 0.8
# * Hue : Normal
# * OD280/OD315 of diluted wines : very less right skewed
# * Proline : right skewed , skewness is 0.7

# %%
Cols_to_normalize=['Malic acid', 'Ash', 'Alcalinity of ash',
       'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
       'Proanthocyanins', 'Color intensity', 'OD280/OD315 of diluted wines', 'Proline']

# %%
#After Normalizing
i=1
plt.figure(figsize=(20,70))
for feature in Cols_to_normalize:
        #boxcox
        Normalize_value, lamb = sp.stats.boxcox(ds1[feature])
        Normal_Boxcox = (((ds1[feature]**lamb) - 1) /lamb)

        #histogram
        plt.subplot(13,3,i)
        sns.histplot(x=Normal_Boxcox,kde= True,color="#BB2525")
        plt.title("Histogram for {}".format(feature))
        i+=1
        # Boxplot
        plt.subplot(13,3,i)
        sns.boxplot(y=Normal_Boxcox,data = Normal_Boxcox)
        plt.title("Boxplot for {}".format(feature))
        i+=1
        #probplot
        plt.subplot(13,3,i)
        sp.stats.probplot(x=Normal_Boxcox, plot=plt)
        plt.title("Probability plot for {}".format(feature))
        plt.legend(labels=[f'skew:{Normal_Boxcox.skew()}'],loc = 'lower right')
        i+=1
